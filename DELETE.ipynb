# %%
from ultralytics import YOLO

# Load model YOLO dengan weight
model = YOLO("backend/best_model/yolov12-s.pt")  # Ganti dengan path weight yang Anda gunakan

# %%
device = model.device
print(f"Model is using device: {device}")
# Out:
# Model is using device: cpu

# %%
# Prediksi pada video
results = model("backend/videos/test_videos/test_videos.mp4", save=True)  # Ganti dengan path video Anda
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/300) c:\Users\abiyamf\Documents\Dicoding\TelU-Tugas-TrendPadaVisiKomputer-FootballPlayerDetection\backend\videos\test_videos\test_videos.mp4: 384x640 21 players, 1 referee, 75.0ms
# video 1/1 (frame 2/300) c:\Users\abiyamf\Documents\Dicoding\TelU-Tugas-TrendPadaVisiKomputer-FootballPlayerDetection\backend\videos\test_videos\test_videos.mp4: 384x640 1 ball, 23 players, 1 referee, 68.0ms
# ...
